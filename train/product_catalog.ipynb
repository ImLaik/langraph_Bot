# %% [markdown]
# ## Training

# %%
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_openai import AzureOpenAIEmbeddings
import json
import os

# %%
# --- Helpers ---
def _require_env(var: str) -> str:
    value = os.getenv(var)
    if not value:
        raise EnvironmentError(f"Missing required environment variable: {var}")
    return value

# %%
# --- Environment Vars ---
AZURE_ENDPOINT = _require_env("AZURE_OPENAI_ENDPOINT")
AZURE_API_KEY = _require_env("AZURE_OPENAI_API_KEY")
AZURE_API_VERSION = _require_env("AZURE_OPENAI_API_VERSION")
DEFAULT_EMBED_MODEL = _require_env("AZURE_OPENAI_EMBEDDING_MODEL")

# %%
# --- Embeddings ---
embeddings = AzureOpenAIEmbeddings(
    azure_deployment=DEFAULT_EMBED_MODEL,
    openai_api_key=AZURE_API_KEY,
    azure_endpoint=AZURE_ENDPOINT,
    openai_api_version=AZURE_API_VERSION,
)

# %%
# --- Setup Chroma store ---
collection_name = "product_catalog"
vector_db_dir = r"C:\Production\Langraph Master Bot\VectorStore\product_catalog"
vectorstore = Chroma(
    collection_name=collection_name,
    persist_directory=vector_db_dir,
    embedding_function=embeddings,
)

# %%
product_catalog_path = r"C:\Production\Langraph Master Bot\query_router\product_catalog.json"

# %%
with open(product_catalog_path, "r") as f:
    catalog = json.load(f)

# %%
# --- Prepare documents ---
documents = []
for solution in catalog:
    for module in solution["modules"]:
        entry_text = (
            f"{module['title']} — {module['description']} "
            f"Keywords: {', '.join(module['keywords'])} "
            f"Capabilities: {', '.join(module['capabilities'])}"
        )
        metadata = {
            "solution": solution["solution"],
            "title": module["title"],
            "slug": module["slug"],
            "url_pattern": module["url_pattern"],
            "industries": ", ".join(module["industries"]),  # flatten lists
            "industry_slugs": ", ".join(module["industry_slugs"])
        }
        documents.append(Document(page_content=entry_text, metadata=metadata))

# %%
# --- Add to vector store ---
vectorstore.add_documents(documents)
# Out:
# ['10b69574-d052-4a57-b489-9176e51b3ff1',
#  'e02e14bd-4203-4fb7-904f-5b9f4a1239e3',
#  'cbcc7641-78b2-4479-af30-0dfd64c9a348',
#  '26ca1f92-7c08-40ca-aa41-5aa07fb24f08',
#  '1fb3d434-600d-41d4-beb8-6122291064ca',
#  'a89524b6-3a46-4441-825c-138cbe2a90c2',
#  '1db1fdb7-5a7e-450e-aa89-f8024fdc8b28',
#  'e89355c4-e0a1-4294-b105-a749d965fa63',
#  '8afee901-7c65-410e-8363-41e291083d82',
#  '96a73ac9-039e-4360-91ec-01568f85d139',
#  '214a1cbf-370c-47ca-a8e5-43d931dcd8c8',
#  '17a12e46-e7ed-4731-9e66-8794d04f2090',
#  'bd175685-6d93-412e-9c69-f15e0c12ed2c',
#  '710d6121-7bbf-422a-a87b-169e6283a45a',
#  '811f95fa-4354-4055-b8bf-89449bafcaca',
#  '7f02f661-d5e3-4380-a28e-54ea4c75da5a',
#  '15c7a6e3-36e8-401a-a71e-3023b0e53981',
#  '7da14464-8958-45aa-a6cc-3995f9847344',
#  'c3d2ed48-45fe-49e9-bcde-29534372df2f',
#  '6bb57576-0897-4e0d-ba62-9292ec98ef4c',
#  '056f9afe-aa0c-4eca-a675-fba5b2c9279d',
#  'e3c31c85-39aa-44cf-bb5b-dedf5adc937d',
#  'df33a3f6-de2e-42b8-b6e5-f126936098bb',
#  '5216c6d5-2497-42d4-bcf1-71a5636f3504',
#  'f17bd926-756f-43d5-b05c-b871012924df',
#  'b1d78141-f008-413d-b562-b1aeaa66ca1c',
#  '61decfea-2f9e-45a6-9c17-6cbb6f0677c6',
#  'e576c467-1a6e-4d7b-9980-35f52a98849b',
#  'c5d53d15-512d-4caa-9b47-f5f2aaa04988',
#  '43dbc779-7a55-40a4-8390-829094515158',
#  'a0340cb0-bb79-4e98-a15e-749006cfaeab']

# %% [markdown]
# ## Testing

# %%
vectorstore = Chroma(
    collection_name=collection_name,
    persist_directory=vector_db_dir,
    embedding_function=embeddings
)

query = "Which brokers currently have the most high-priority cases?"
results = vectorstore.similarity_search(query, k=3)

for r in results:
    print(r.metadata["title"], r.metadata["url_pattern"], r.page_content)
# Out:
# Priority Bin Dashboard https://www.spinnakerhub.com/lead-prioritizer/{industry-slug}/priority-bin-dashboard Priority Bin Dashboard — Interactive pipeline and priority segmentation dashboard that categorizes applications into priority bins (High Priority, Normal, Low, DTQ) and tracks case counts, premiums, and conversion metrics for each bin. Displays key KPIs including total cases, sold count, % sold, total premium, and expected premium. Visualizations include application mix by priority bin, total premium by bin, expected premium by bin, average case score by bin, and expected sold ratio by bin, with pipeline averages highlighted for comparison. Users can filter by product, application type, underwriter, broker, state, and income bin to evaluate performance drivers and prioritize sales activities for the most promising cases. Keywords: priority bin, high priority cases, normal priority, low priority, DTQ cases, pipeline value, expected premium, total premium, case score analysis, expected sold ratio, priority mix, priority segmentation, application mix Capabilities: Categorize applications into High Priority, Normal, Low, and DTQ bins, Track case counts per priority bin, View total and expected premium by priority category, Analyze average case score for each bin vs pipeline average, Compare expected sold ratio to pipeline average, Filter results by product, application type, underwriter, broker, state, and income bin, Identify opportunities in high priority bins for targeted follow-up, Assess sales potential and conversion likelihood by priority category, Visualize pipeline distribution for workload balancing and targeting
# Work Inventory https://www.spinnakerhub.com/lead-prioritizer/{industry-slug}/work-inventory Work Inventory — Comprehensive case-level inventory dashboard tracking applications across multiple dimensions including demographics, financials, product type, status, underwriting details, and risk assessment. Displays sortable table columns such as Case ID, Submit Date, Age, Gender, BMI, State, Income, Tobacco use, Application Type, Product, Face Amount, Broker, Status (Open/Complete), Underwriter, Lead Score, Priority level (High, Normal, Low, DTQ), Assessment (risk categorization), and Client Name. Enables filtering by case attributes, product type, geography, and priority to track work volumes, monitor case progression, and assess risk levels. Supports workflow management by highlighting high-priority cases for immediate action and identifying bottlenecks in processing. Keywords: case inventory, case tracking, workflow management, lead score, priority level, risk assessment, application tracking, broker tracking, underwriter monitoring, face amount, application type, processing bottlenecks Capabilities: Display full case inventory with sortable and filterable columns, Filter cases by product type, geography, broker, underwriter, and risk category, View detailed applicant demographic and financial data, Monitor case status (Open/Complete) for workflow tracking, Highlight and prioritize cases based on lead score and priority label, Review underwriting assignments and broker relationships, Assess risk using the Assessment column with categories such as Declined, Low Risk, Medium Risk, Track face amounts and product types for portfolio balance analysis, Identify bottlenecks by monitoring cases in specific workflow stages
# Score Calculator https://www.spinnakerhub.com/lead-prioritizer/{industry-slug}/score-calculator Score Calculator — Interactive tool for generating real-time case scores based on detailed customer and application attributes, with automatic classification into priority levels (DTQ, Low Priority, Normal Priority, High Priority). Users can input data including age, height, weight, gender, alcohol consumption, nicotine use, state, application type, product type, broker, received month, annual income, and face amount. Displays resulting case score alongside priority category, and visualizes factor impacts using a Percentile Contribution Chart. Supports scenario adjustments by modifying any attribute, allowing scoring weight analysis and export of results for integration with case databases. Keywords: case scoring, risk scoring, underwriting score, score calculator, priority classification, DTQ priority, low priority case, normal priority case, high priority case, percentile contribution analysis, sales propensity score Capabilities: Enter detailed case attributes for scoring, Generate case score instantly based on sales propensity, Automatically classify case into DTQ, Low, Normal, or High Priority ranges, Visualize factor contributions in a Percentile Contribution Chart, Modify attribute values to test score sensitivity and impact, Export scoring results for external tracking or reporting, Integrate score output with case databases, Support strategic prioritization of cases based on calculated score
