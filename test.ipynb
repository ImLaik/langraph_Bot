# %%
import pandas as pd

# %%
# Load your file
df = pd.read_csv("Spinnaker Bot Mapping.csv")  # Change to read_csv() if your file is CSV

# %%
df.head()
# Out:
#                                           url       Products Product Catalog  \
# 0  https://www.spinnakerhub.com/sales-prophet  Sales Prophet             MOG
# 1                                         NaN  Sales Prophet             MOG
# 2                                         NaN  Sales Prophet             MOG
# 3                                         NaN  Sales Prophet             MOG
# 4                                         NaN  Sales Prophet  Sales Planning
#
#     Product Catalog Module                         Product Catalog Module url  \
# 0           M Intelligence  https://www.spinnakerhub.com/sales-prophet/ind...
# 1             Wallet Share  https://www.spinnakerhub.com/sales-prophet/ind...
# 2               Sales Opty  https://www.spinnakerhub.com/sales-prophet/ind...
# 3        Agent Performance  https://www.spinnakerhub.com/sales-prophet/ind...
# 4  Intelligent Goal Setter  https://www.spinnakerhub.com/sales-prophet/ind...
#
#                              Report id? Database? Industries Data Source  \
# 0  8a1e9e9e-2200-4ed2-87dd-73779b23384e         Y         IL          PG
# 1  de878502-5307-4254-acac-ae1496405107         Y         IL          PG
# 2  3d975db2-c000-423f-9c9b-79dff4460edf         Y         IL          PG
# 3  1c39996f-80bd-4438-b415-db651849a0ac         Y         IL          PG
# 4  fe0a85b2-3194-42b9-b59f-5cacf8eb786e       NaN         IL         NaN
#
#                                      Relevant Tables   Agent/Tool  \
# 0  [il_mi_population, il_mi_life_agents_by_zipcod...  SQL_QA_Tool
# 1  [il_mi_mog, il_mi_client_dummy, il_mi_master_geo]  SQL_QA_Tool
# 2               [il_mi_sales_opty, il_mi_master_geo]  SQL_QA_Tool
# 3  [il_mi_master_geo, il_mi_life_agents_by_zipcod...  SQL_QA_Tool
# 4                                                 []          NaN
#
#                                             Keywords Data Dictionary   \
# 0  [market intelligence, market overview, market ...  MOG_IL_DATA_DIC
# 1        [wallet share, policy share, premium share]  MOG_IL_DATA_DIC
# 2                    [sales opportunity, sales opty]  MOG_IL_DATA_DIC
# 3  [agent performance, agent count, market agents...  MOG_IL_DATA_DIC
# 4                                                NaN              NaN
#
#      Tool_Prompt
# 0  MOG_IL_PROMPT
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# 2. Remove leading/trailing spaces from column names
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['url', 'Products', 'Product Catalog', 'Product Catalog Module',
#        'Product Catalog Module url', 'Report id?', 'Database?', 'Industries',
#        'Data Source', 'Relevant Tables', 'Agent/Tool', 'Keywords',
#        'Data Dictionary', 'Tool_Prompt'],
#       dtype='object')

# %%
len(df)
# Out:
# 55

# %%
# 3. Remove duplicate rows
df = df.drop_duplicates()

# %%
df
# Out:
#                                            url       Products  \
# 0   https://www.spinnakerhub.com/sales-prophet  Sales Prophet
# 1                                          NaN  Sales Prophet
# 2                                          NaN  Sales Prophet
# 3                                          NaN  Sales Prophet
# 4                                          NaN  Sales Prophet
# 5                                          NaN  Sales Prophet
# 6                                          NaN  Sales Prophet
# 7                                          NaN  Sales Prophet
# 8                                          NaN  Sales Prophet
# 9                                          NaN  Sales Prophet
# 10                                         NaN  Sales Prophet
# 11                                         NaN  Sales Prophet
# 12                                         NaN  Sales Prophet
# 13                                         NaN  Sales Prophet
# 14                                         NaN  Sales Prophet
# 15                                         NaN  Sales Prophet
# 16                                         NaN  Sales Prophet
# 17                                         NaN  Sales Prophet
# 18                                         NaN  Sales Prophet
# 19                                         NaN  Sales Prophet
# 20                                         NaN  Sales Prophet
# 21                                         NaN  Sales Prophet
# 22  https://www.spinnakerhub.com/sales-prophet  Sales Prophet
# 23                                         NaN  Sales Prophet
# 30                                         NaN  Sales Prophet
# 34                                         NaN  Sales Prophet
# 35                                         NaN  Sales Prophet
# 37                                         NaN  Sales Prophet
# 45                                         NaN  Sales Prophet
# 52                                         NaN  Sales Prophet
#
#        Product Catalog   Product Catalog Module  \
# 0                  MOG           M Intelligence
# 1                  MOG             Wallet Share
# 2                  MOG               Sales Opty
# 3                  MOG        Agent Performance
# 4       Sales Planning  Intelligent Goal Setter
# 5       Sales Planning             Sales Funnel
# 6   Territory Designer         Territory Design
# 7   Territory Designer    Territory Design Tool
# 8    Broker Score Card        Broker Score Card
# 9              InsurIQ                  InsurIQ
# 10                 MOG           M Intelligence
# 11                 MOG           M Intelligence
# 12                 MOG           M Intelligence
# 13                 MOG           M Intelligence
# 14      Sales Planning  Intelligent Goal Setter
# 15      Sales Planning  Intelligent Goal Setter
# 16      Sales Planning             Sales Funnel
# 17      Sales Planning             Sales Funnel
# 18      Sales Planning             Sales Funnel
# 19      Sales Planning             Sales Funnel
# 20      Sales Planning             Sales Funnel
# 21      Sales Planning             Sales Funnel
# 22                 MOG           M Intelligence
# 23                 MOG             Wallet Share
# 30   Broker Score Card        Broker Score Card
# 34                 MOG           M Intelligence
# 35                 MOG           M Intelligence
# 37      Sales Planning  Intelligent Goal Setter
# 45                 MOG             Wallet Share
# 52   Broker Score Card        Broker Score Card
#
#                            Product Catalog Module url  \
# 0   https://www.spinnakerhub.com/sales-prophet/ind...
# 1   https://www.spinnakerhub.com/sales-prophet/ind...
# 2   https://www.spinnakerhub.com/sales-prophet/ind...
# 3   https://www.spinnakerhub.com/sales-prophet/ind...
# 4   https://www.spinnakerhub.com/sales-prophet/ind...
# 5   https://www.spinnakerhub.com/sales-prophet/ind...
# 6   https://www.spinnakerhub.com/sales-prophet/ind...
# 7   https://www.spinnakerhub.com/sales-prophet/ind...
# 8   https://www.spinnakerhub.com/sales-prophet/emp...
# 9   https://www.spinnakerhub.com/sales-prophet/pro...
# 10  https://www.spinnakerhub.com/sales-prophet/ann...
# 11  https://www.spinnakerhub.com/sales-prophet/wor...
# 12  https://www.spinnakerhub.com/sales-prophet/emp...
# 13  https://www.spinnakerhub.com/sales-prophet/wea...
# 14  https://www.spinnakerhub.com/sales-prophet/emp...
# 15  https://www.spinnakerhub.com/sales-prophet/pro...
# 16  https://www.spinnakerhub.com/sales-prophet/ann...
# 17  https://www.spinnakerhub.com/sales-prophet/pro...
# 18  https://www.spinnakerhub.com/sales-prophet/emp...
# 19  https://www.spinnakerhub.com/sales-prophet/rei...
# 20  https://www.spinnakerhub.com/sales-prophet/bro...
# 21  https://www.spinnakerhub.com/sales-prophet/wea...
# 22  https://www.spinnakerhub.com/sales-prophet/ind...
# 23  https://www.spinnakerhub.com/sales-prophet/ind...
# 30  https://www.spinnakerhub.com/sales-prophet/emp...
# 34  https://www.spinnakerhub.com/sales-prophet/emp...
# 35  https://www.spinnakerhub.com/sales-prophet/wea...
# 37  https://www.spinnakerhub.com/sales-prophet/pro...
# 45  https://www.spinnakerhub.com/sales-prophet/ind...
# 52  https://www.spinnakerhub.com/sales-prophet/emp...
#
#                               Report id? Database?         Industries  \
# 0   8a1e9e9e-2200-4ed2-87dd-73779b23384e         Y                 IL
# 1   de878502-5307-4254-acac-ae1496405107         Y                 IL
# 2   3d975db2-c000-423f-9c9b-79dff4460edf         Y                 IL
# 3   1c39996f-80bd-4438-b415-db651849a0ac         Y                 IL
# 4   fe0a85b2-3194-42b9-b59f-5cacf8eb786e       NaN                 IL
# 5                                    NaN       NaN                 IL
# 6   ef4917ad-12cd-42cf-bc1f-a81920c6ba2d       NaN                 IL
# 7                                    NaN       NaN                 IL
# 8   1531a467-b7ee-4e73-a4a2-c769fdd67932       NaN                 EB
# 9                                    NaN       NaN                P&C
# 10  bcfe32b5-e29d-4a34-806f-00e98ebedbae         Y            Annuity
# 11  1081f7cc-174e-4e51-8440-93e5ed4ebf7e         Y           Worksite
# 12  25cf6e7e-1f45-4101-a47f-0882b6c9b262         Y                 EB
# 13  73ebf4d9-69b2-416b-9810-f0ac7ff8fba1         Y  Wealth Management
# 14  e1a68e06-705f-4b03-8a3d-be6e9cbb8b8b       NaN                 EB
# 15  d6d216d3-bfb2-4334-905f-e3431e555be4       NaN                P&C
# 16                                   NaN       NaN            Annuity
# 17                                   NaN       NaN                P&C
# 18                                   NaN       NaN                 EB
# 19                                   NaN       NaN        Reinsurance
# 20                                   NaN       NaN            Brokers
# 21                                   NaN       NaN  Wealth Management
# 22  8a1e9e9e-2200-4ed2-87dd-73779b23384e         Y                 IL
# 23  de878502-5307-4254-acac-ae1496405108         Y                 IL
# 30  1531a467-b7ee-4e73-a4a2-c769fdd67933       NaN                 EB
# 34  25cf6e7e-1f45-4101-a47f-0882b6c9b263         Y                 EB
# 35  73ebf4d9-69b2-416b-9810-f0ac7ff8fba2         Y  Wealth Management
# 37  d6d216d3-bfb2-4334-905f-e3431e555be5       NaN                P&C
# 45  de878502-5307-4254-acac-ae1496405109         Y                 IL
# 52  1531a467-b7ee-4e73-a4a2-c769fdd67934       NaN                 EB
#
#       Data Source                                    Relevant Tables  \
# 0              PG  [il_mi_population, il_mi_life_agents_by_zipcod...
# 1              PG  [il_mi_mog, il_mi_client_dummy, il_mi_master_geo]
# 2              PG               [il_mi_sales_opty, il_mi_master_geo]
# 3              PG  [il_mi_master_geo, il_mi_life_agents_by_zipcod...
# 4             NaN                                                 []
# 5           Image                                                 []
# 6             NaN                                                NaN
# 7             NaN                                                NaN
# 8             NaN  [eb_bsc_inforce_es, eb_bsc_pol_by_pol_es, eb_b...
# 9             NaN                                                NaN
# 10             PG  [annuity_mog_data, mi_master_geo, il_mi_income...
# 11             PG  [worksite_mog_data, workste_employers_and_esta...
# 12  DirectLake???                                                NaN
# 13             PG                   [il_mi_income, il_mi_population]
# 14            NaN                                                NaN
# 15            NaN                                                NaN
# 16            NaN                                                NaN
# 17            NaN                                                NaN
# 18            NaN                                                NaN
# 19            NaN                                                NaN
# 20            NaN                                                NaN
# 21            NaN                                                NaN
# 22             PG  [mi_master_geo, il_mi_income, il_mi_population...
# 23             PG  [il_mi_mog, il_mi_client_dummy, il_mi_master_geo]
# 30            NaN  [eb_bsc_inforce_es, eb_bsc_pol_by_pol_es, eb_b...
# 34  DirectLake???                                                NaN
# 35             PG                   [il_mi_income, il_mi_population]
# 37            NaN                                                NaN
# 45             PG  [il_mi_mog, il_mi_client_dummy, il_mi_master_geo]
# 52            NaN  [eb_bsc_inforce_es, eb_bsc_pol_by_pol_es, eb_b...
#
#                                            Agent/Tool  \
# 0                                         SQL_QA_Tool
# 1                                         SQL_QA_Tool
# 2                                         SQL_QA_Tool
# 3                                         SQL_QA_Tool
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  [market premium, market policies, total premiu...
# 11  [total [premium, total policies, market premiu...
# 12                                                 []
# 13             [income, population, household income]
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                        SQL_QA_Tool
# 23                                        SQL_QA_Tool
# 30                                                NaN
# 34                                                 []
# 35             [income, population, household income]
# 37                                                NaN
# 45                                        SQL_QA_Tool
# 52                                                NaN
#
#                                              Keywords  \
# 0   [market intelligence, market overview, market ...
# 1         [wallet share, policy share, premium share]
# 2                     [sales opportunity, sales opty]
# 3   [agent performance, agent count, market agents...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  [market intelligence, market overview, market ...
# 23        [wallet share, policy share, premium share]
# 30                                                NaN
# 34                                                NaN
# 35                                                NaN
# 37                                                NaN
# 45        [wallet share, policy share, premium share]
# 52                                                NaN
#
#                    Data Dictionary    Tool_Prompt
# 0                  MOG_IL_DATA_DIC  MOG_IL_PROMPT
# 1                  MOG_IL_DATA_DIC            NaN
# 2                  MOG_IL_DATA_DIC            NaN
# 3                  MOG_IL_DATA_DIC            NaN
# 4                              NaN            NaN
# 5                              NaN            NaN
# 6                              NaN            NaN
# 7                              NaN            NaN
# 8                              NaN            NaN
# 9                              NaN            NaN
# 10            MOG_Annuity_DATA_DIC            NaN
# 11           MOG_Worksite_DATA_DIC            NaN
# 12                             NaN            NaN
# 13  MOG_Wealth_Management_DATA_DIC            NaN
# 14                             NaN            NaN
# 15                             NaN            NaN
# 16                             NaN            NaN
# 17                             NaN            NaN
# 18                             NaN            NaN
# 19                             NaN            NaN
# 20                             NaN            NaN
# 21                             NaN            NaN
# 22                 MOG_IL_DATA_DIC            NaN
# 23                 MOG_IL_DATA_DIC            NaN
# 30                             NaN            NaN
# 34                             NaN            NaN
# 35  MOG_Wealth_Management_DATA_DIC            NaN
# 37                             NaN            NaN
# 45                 MOG_IL_DATA_DIC            NaN
# 52                             NaN            NaN

# %%
df.to_csv("tool_mapping.csv", index=False)
